# %%
# %sql
-- Add a quality enforcement on a table that is already created 
ALTER TABLE dev.silver.orders_silver ADD CONSTRAINT timestamp_within_range CHECK (order_timestamp >= '2020-01-01')

# %%
# %sql
DESC EXTENDED dev.silver.orders_silver

# %%
# %sql
INSERT INTO dev.silver.orders_silver
VALUES ('1f', '2022-02-01 00:00:00.000', 'C00001', 0, 0, NULL),
       ('2f', '2019-02-01 00:00:00.000', 'C00002', 0, 0, NULL),
       ('3f', '2023-02-01 00:00:00.000', 'C00003', 0, 0, NULL)

# %%
# %sql
SELECT 
    *
FROM dev.silver.orders_silver
WHERE order_id in ('1f', '2f', '3f')

# %%
# %sql
ALTER TABLE dev.silver.orders_silver ADD CONSTRAINT valid_quantity CHECK (quantity > 0)

# %%
# %sql
DESCRIBE EXTENDED dev.silver.orders_silver

# %%
# %sql
-- Let us check the orders with quantity less than or equal to 0 
select * from dev.silver.orders_silver where quantity <= 0

# %%
# %sql
-- Now we can add a constraint to the existing table to check the quality of quantity column 
ALTER TABLE dev.silver.orders_silver ADD CONSTRAINT positive_quantity CHECK (quantity > 0)

# %%
# %sql 
DESC EXTENDED dev.silver.orders_silver

# %%
# %sql 
-- Now let us drop the table and remove checkpointLocation 
DROP TABLE IF EXISTS dev.silver.orders_silver

# %%
dbutils.fs.rm('/Volumes/dev/pro_landing_zone/checkpoints/silver_orders/', True)
